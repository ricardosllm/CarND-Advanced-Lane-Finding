# %% [markdown]
# # Advanced Lane Finding

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.gridspec as gridspec
import glob
import cv2

# %matplotlib inline

# %% [markdown]
# ## Camera Calibration

# %%
from alf.camera import Camera

cal_images = Camera(glob.glob('camera_cal/calibration*.jpg'))

plt.figure(figsize=(11.5, 9))
gridspec.GridSpec(5, 4)

print('Corners detected:')
# Loop through the images and look for the chessboard corners
for i, image, in enumerate(cal_images.calibrated_images):
    plt.subplot2grid((5, 4), (i//4, i%4), colspan=1, rowspan=1)
    plt.imshow(image)
    plt.axis('off')
plt.show()

print('Unable to detect corners:')
for i, image in enumerate(cal_images.failed_images):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 2.5))
    ax1.axis('off')
    ax1.imshow(image)
    ax1.set_title('Original', fontsize=10)
    ax2.axis('off')
    ax2.imshow(cal_images(image))
    ax2.set_title('Calibrated', fontsize=10)
# Out:
# Corners detected:
# Unable to detect corners:
